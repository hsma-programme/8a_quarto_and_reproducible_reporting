# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("data/youtoxic_english_1000.csv")
df.head(3)
# Out:
#               CommentId      VideoId  \
# 0  Ugg2KwwX0V8-aXgCoAEC  04kJtp6pVXI
# 1  Ugg2s5AzSPioEXgCoAEC  04kJtp6pVXI
# 2  Ugg3dWTOxryFfHgCoAEC  04kJtp6pVXI
#
#                                                 Text  IsToxic  IsAbusive  \
# 0  If only people would just take a step back and...    False      False
# 1  Law enforcement is not trained to shoot to app...     True       True
# 2  \nDont you reckon them 'black lives matter' ba...     True       True
#
#    IsThreat  IsProvocative  IsObscene  IsHatespeech  IsRacist  IsNationalist  \
# 0     False          False      False         False     False          False
# 1     False          False      False         False     False          False
# 2     False          False       True         False     False          False
#
#    IsSexist  IsHomophobic  IsReligiousHate  IsRadicalism
# 0     False         False            False         False
# 1     False         False            False         False
# 2     False         False            False         False

# %%
# show the columns
df.columns
# Out:
# Index(['CommentId', 'VideoId', 'Text', 'IsToxic', 'IsAbusive', 'IsThreat',
#        'IsProvocative', 'IsObscene', 'IsHatespeech', 'IsRacist',
#        'IsNationalist', 'IsSexist', 'IsHomophobic', 'IsReligiousHate',
#        'IsRadicalism'],
#       dtype='object')

# %%
# filter the categories to a new dataframe
categories_df = df[['IsToxic', 'IsAbusive', 'IsThreat',
       'IsProvocative', 'IsObscene', 'IsHatespeech', 'IsRacist',
       'IsNationalist', 'IsSexist', 'IsHomophobic', 'IsReligiousHate',
       'IsRadicalism']]

categories_df.head(2)
# Out:
#    IsToxic  IsAbusive  IsThreat  IsProvocative  IsObscene  IsHatespeech  \
# 0    False      False     False          False      False         False
# 1     True       True     False          False      False         False
#
#    IsRacist  IsNationalist  IsSexist  IsHomophobic  IsReligiousHate  \
# 0     False          False     False         False            False
# 1     False          False     False         False            False
#
#    IsRadicalism
# 0         False
# 1         False

# %%
# sum the categories
category_counts = categories_df.sum().sort_values(ascending=False)

# set up the figure
figure_1, ax = plt.subplots(figsize=(6, 4))

# labels
ax.set_xlabel('Category')
ax.set_ylabel('Number of Comments')
ax.set_title('Occurrence of "True" in Each Category')

# bar plot
ax.bar(category_counts.index, category_counts.values, color='red')

# rotate labels
ax.set_xticklabels(category_counts.index, rotation=90)

# display the figure
figure_1.show()
# Out:
# C:\Users\saman\AppData\Local\Temp\ipykernel_2608\4169057356.py:16: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(category_counts.index, rotation=90)
# C:\Users\saman\AppData\Local\Temp\ipykernel_2608\4169057356.py:19: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   figure_1.show()

# %%
# remove the categories that are under 100
filtered_columns = categories_df.columns[categories_df.sum() >= 100]
filtered_df = categories_df[filtered_columns]
filtered_df.head(5)
# Out:
#    IsToxic  IsAbusive  IsProvocative  IsObscene  IsHatespeech  IsRacist
# 0    False      False          False      False         False     False
# 1     True       True          False      False         False     False
# 2     True       True          False       True         False     False
# 3    False      False          False      False         False     False
# 4    False      False          False      False         False     False

# %%
# correlation table
corr = filtered_df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_005b3_row0_col0, #T_005b3_row1_col1, #T_005b3_row2_col2, #T_005b3_row3_col3, #T_005b3_row4_col4, #T_005b3_row5_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_005b3_row0_col1 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_005b3_row0_col2, #T_005b3_row3_col1 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_005b3_row0_col3 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_005b3_row0_col4 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_005b3_row0_col5, #T_005b3_row1_col3 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_005b3_row1_col0 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_005b3_row1_col2 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_005b3_row1_col4, #T_005b3_row1_col5, #T_005b3_row3_col0, #T_005b3_row4_col1, #T_005b3_row4_col2, #T_005b3_row5_col1, #T_005b3_row5_col2, #T_005b3_row5_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_005b3_row2_col0 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_005b3_row2_col1 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_005b3_row2_col3 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_005b3_row2_col4, #T_005b3_row2_col5 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_005b3_row3_col2 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_005b3_row3_col4 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_005b3_row3_col5, #T_005b3_row5_col0 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_005b3_row4_col0 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_005b3_row4_col3 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_005b3_row4_col5, #T_005b3_row5_col4 {
#   background-color: #c53334;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_005b3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_005b3_level0_col0" class="col_heading level0 col0" >IsToxic</th>
#       <th id="T_005b3_level0_col1" class="col_heading level0 col1" >IsAbusive</th>
#       <th id="T_005b3_level0_col2" class="col_heading level0 col2" >IsProvocative</th>
#       <th id="T_005b3_level0_col3" class="col_heading level0 col3" >IsObscene</th>
#       <th id="T_005b3_level0_col4" class="col_heading level0 col4" >IsHatespeech</th>
#       <th id="T_005b3_level0_col5" class="col_heading level0 col5" >IsRacist</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_005b3_level0_row0" class="row_heading level0 row0" >IsToxic</th>
#       <td id="T_005b3_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_005b3_row0_col1" class="data row0 col1" >0.797086</td>
#       <td id="T_005b3_row0_col2" class="data row0 col2" >0.472718</td>
#       <td id="T_005b3_row0_col3" class="data row0 col3" >0.359707</td>
#       <td id="T_005b3_row0_col4" class="data row0 col4" >0.431774</td>
#       <td id="T_005b3_row0_col5" class="data row0 col5" >0.407869</td>
#     </tr>
#     <tr>
#       <th id="T_005b3_level0_row1" class="row_heading level0 row1" >IsAbusive</th>
#       <td id="T_005b3_row1_col0" class="data row1 col0" >0.797086</td>
#       <td id="T_005b3_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_005b3_row1_col2" class="data row1 col2" >0.593057</td>
#       <td id="T_005b3_row1_col3" class="data row1 col3" >0.451277</td>
#       <td id="T_005b3_row1_col4" class="data row1 col4" >-0.119603</td>
#       <td id="T_005b3_row1_col5" class="data row1 col5" >-0.121005</td>
#     </tr>
#     <tr>
#       <th id="T_005b3_level0_row2" class="row_heading level0 row2" >IsProvocative</th>
#       <td id="T_005b3_row2_col0" class="data row2 col0" >0.472718</td>
#       <td id="T_005b3_row2_col1" class="data row2 col1" >0.593057</td>
#       <td id="T_005b3_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_005b3_row2_col3" class="data row2 col3" >0.089788</td>
#       <td id="T_005b3_row2_col4" class="data row2 col4" >-0.072719</td>
#       <td id="T_005b3_row2_col5" class="data row2 col5" >-0.075072</td>
#     </tr>
#     <tr>
#       <th id="T_005b3_level0_row3" class="row_heading level0 row3" >IsObscene</th>
#       <td id="T_005b3_row3_col0" class="data row3 col0" >0.359707</td>
#       <td id="T_005b3_row3_col1" class="data row3 col1" >0.451277</td>
#       <td id="T_005b3_row3_col2" class="data row3 col2" >0.089788</td>
#       <td id="T_005b3_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_005b3_row3_col4" class="data row3 col4" >-0.027061</td>
#       <td id="T_005b3_row3_col5" class="data row3 col5" >-0.035277</td>
#     </tr>
#     <tr>
#       <th id="T_005b3_level0_row4" class="row_heading level0 row4" >IsHatespeech</th>
#       <td id="T_005b3_row4_col0" class="data row4 col0" >0.431774</td>
#       <td id="T_005b3_row4_col1" class="data row4 col1" >-0.119603</td>
#       <td id="T_005b3_row4_col2" class="data row4 col2" >-0.072719</td>
#       <td id="T_005b3_row4_col3" class="data row4 col3" >-0.027061</td>
#       <td id="T_005b3_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_005b3_row4_col5" class="data row4 col5" >0.944637</td>
#     </tr>
#     <tr>
#       <th id="T_005b3_level0_row5" class="row_heading level0 row5" >IsRacist</th>
#       <td id="T_005b3_row5_col0" class="data row5 col0" >0.407869</td>
#       <td id="T_005b3_row5_col1" class="data row5 col1" >-0.121005</td>
#       <td id="T_005b3_row5_col2" class="data row5 col2" >-0.075072</td>
#       <td id="T_005b3_row5_col3" class="data row5 col3" >-0.035277</td>
#       <td id="T_005b3_row5_col4" class="data row5 col4" >0.944637</td>
#       <td id="T_005b3_row5_col5" class="data row5 col5" >1.000000</td>
#     </tr>
#   </tbody>
# </table>
